# %%
from __future__ import print_function
import pandas as pd
import matplotlib.pyplot as plt
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

player = 'Jack Eichel'

faceoff_data = pd.read_csv('data/faceoff_data.csv')

#faceoff_data.groupby('player').count()

players = faceoff_data.player.unique()

# [TODO] That's close. Need to filter out to players who have taken more than 20 faceoffs
players


#player_control = widgets.Dropdown(options=players)

#display(player_control)

#player = player_control.value

#faceoff_data.tail(20)
# Out:
# array(['Travis Boyd', 'David Kampf', 'Connor McMichael',
#        'Matthew Highmore', 'Aliaksei Protas', 'Jacob Nilsson',
#        'Ryan Carpenter', 'Nic Dowd', 'Dylan Sikura', 'Tom Wilson',
#        'John Quenneville', 'Garnet Hathaway', 'Kris Versteeg',
#        'Anthony Cirelli', 'Lucas Wallmark', 'Ross Colton', 'Ryan Suzuki',
#        'Mitchell Stephens', 'Morgan Geekie', 'Eetu Luostarinen',
#        'Yanni Gourde', 'Steven Stamkos', 'Gabriel Fortier', nan,
#        'Anton Forsberg', 'Janne Kuokkanen', 'Nicklas Backstrom',
#        'Tyler Bozak', 'Evgeny Kuznetsov', 'Ryan Olsen', 'Robby Fabbri',
#        'T.J. Oshie', 'Jaden Schwartz', 'Cameron Darcy', 'Richard Panik',
#        'Beck Malenstyn', 'Nolan Stevens', 'Sebastian Aho',
#        'Chris Mueller', 'Martin Necas', 'Gemel Smith', 'Jordan Staal',
#        'Otto Somppi', 'Erik Haula', 'Clark Bishop', 'Jimmy Huntington',
#        'Cory Conacher', 'Nino Niederreiter', 'Alexander Volkov',
#        'Carter Verhaeghe', 'Teuvo Teravainen', 'Colin White',
#        'William Nylander', 'Brady Tkachuk', 'Auston Matthews',
#        'Tyler Gaudet', 'Nick Paul', 'Alexander Kerfoot', 'Artem Anisimov',
#        'Logan Brown', 'Kalle Kossila', 'Nick Shore', 'Jordan Szwarz',
#        'Matt Read', 'Evgeni Malkin', 'Alexander Wennberg',
#        'Nick Bjugstad', 'Brandon Dubinsky', 'Dominik Simon',
#        'Ryan MacInnis', 'Gustav Nyquist', 'Nathan Legare', 'Zac Dalpe',
#        'Sam Lafferty', 'Sam Poulin', 'Vladimir Sobotka',
#        'Andreas Johnsson', 'Casey Mittelstadt', 'Conor Sheary',
#        'Pontus Aberg', 'Dylan Cozens', 'Curtis Lazar',
#        'Jean-Sebastien Dea', 'Nicholas Shore', 'Kenny Agostino',
#        'Kyle Okposo', 'Arttu Ruotsalainen', 'Dmytro Timashov',
#        'Tyler Johnson', 'Kyle Turris', 'Cedric Paquette',
#        'Frederick Gaudreau', 'Nick Bonino', 'Colin Blackwell',
#        'Rem Pitlick', 'Danick Martel', 'Mikael Granlund',
#        'Calle Jarnkrok', 'Mathieu Olivier', 'Pierre-Luc Dubois',
#        'Justin Scott', 'Joseph Blandisi', 'Jared McCann', 'Nick Foligno',
#        'Andrew Agozzino', 'Kevin Stenlund', 'Boone Jenner',
#        'Teddy Blueger', 'Eric Robinson', 'Anthony Angello',
#        'Jake Lucchini', 'Michael Sgarbossa', 'Carl Hagelin',
#        'Steven Lorentz', 'Garrett Pilon', 'Jack Eichel', 'John Tavares',
#        'Jason Spezza', 'Marcus Johansson', 'Adam Brooks',
#        'Hudson Elynuik', 'Nic Petan', 'Sam Reinhart', 'Jimmy Vesey',
#        'Frederik Gauthier', 'Evan Rodrigues', 'Jeremy Bracco',
#        'Rasmus Asplund', 'Jeff Skinner', 'Matt Duchene', 'Ryan Johansen',
#        'Yakov Trenin', 'Josh Wilkins', 'Colton Sissons',
#        'Alex Barre-Boulet', 'Dylan Larkin', 'Joseph Veleno',
#        'Michael Rasmussen', 'Christoffer Ehn', 'Adam Erne', 'Taro Hirose',
#        'Brandon Tanev', 'Ryan Haggerty', 'Givani Smith', 'Max Domi',
#        'Jesperi Kotkaniemi', 'Jake Evans', 'Nick Cousins',
#        'Pierre Engvall', 'Nate Thompson', 'Matthew Peca', 'Charles Hudon',
#        'Joel Armia', 'Jonathan Drouin', 'Aleksander Barkov',
#        'Denis Malgin', 'Vincent Trocheck', 'Dryden Hunt',
#        'Dominic Toninato', 'Henrik Borgstrom', 'Mathieu Joseph',
#        'Alex Killorn', 'Jonathan Huberdeau', 'Pat Maroon', 'Ondrej Palat',
#        'Frank Vatrano', 'Sidney Crosby', 'Luke Glendening',
#        'Valtteri Filppula', 'Jacob de la Rose', 'Ryan Kuffner',
#        'Turner Elson', 'Patric Hornqvist', 'Jake Guentzel',
#        'Matt Puempel', 'Dominik Kahun', 'Justin Abdelkader',
#        'Chris Terry', 'Darren Helm', 'Phillip Danault', 'Mitchell Marner',
#        'Jordan Weal', 'Nick Suzuki', 'Brendan Gallagher', 'Dylan Strome',
#        'Jonathan Toews', 'Brandon Saad', 'Chandler Stephenson',
#        'Lars Eller', 'Andrew Shaw', 'Brett Connolly', 'Noel Acciari',
#        'Colton Sceviour', 'Evgenii Dadonov', 'Dominic Turgeon',
#        'Filip Zadina', 'Brayden Schenn', 'Nathan Walker',
#        'Austin Poganski', 'Brian Pinho', 'Ivan Barbashev', 'Zach Sanford',
#        'Johan Larsson', 'Tage Thompson', 'Scott Wilson',
#        'Zemgus Girgensons', 'Zach Aston-Reese', 'Anthony Mantha',
#        'Frans Nielsen', 'Ilya Mikheyev', 'Shane Gersich',
#        'Julien Gauthier', 'Brendan Leipsic', 'Jordan Martinook',
#        'Chris Tierney', 'Jean-Gabriel Pageau', 'Anthony Duclair',
#        'Tyler Ennis', 'Connor Brown', 'Drake Batherson', 'Trevor Moore',
#        'Bobby Ryan', "Ryan O'Reilly", 'Oskar Sundqvist', 'Robert Thomas',
#        'David Perron', 'Alexander Steen', 'Tyler Seguin',
#        'Patrice Bergeron', 'Mattias Janmark', 'Sean Kuraly',
#        'Roope Hintz', 'Par Lindholm', 'Blake Comeau', 'Radek Faksa',
#        'Charlie Coyle', 'Jason Dickinson', 'Chris Wagner', 'Jamie Benn',
#        'Andrew Cogliano', 'David Backes', 'Justin Dowling',
#        'Alexander Radulov', 'Joe Pavelski', 'Jake DeBrusk',
#        'Casey Cizikas', 'Brock Nelson', 'Jakub Vrana', 'Derick Brassard',
#        'Mathew Barzal', 'Leo Komarov', 'Anders Lee', 'Josh Bailey',
#        'Jordan Eberle', 'Riley Nash', 'Oliver Bjorkstrand',
#        'Emil Bemstrom', 'Tomas Tatar', 'Mike Hoffman', 'Alexandre Texier',
#        'Brock McGinn', 'Brad Richardson', 'Derek Stepan', 'David Krejci',
#        'Lawson Crouse', 'Christian Dvorak', 'Vinnie Hinostroza',
#        'Carl Soderberg', 'Nick Schmaltz', 'Mark Scheifele', 'Andrew Copp',
#        'Adam Lowry', 'Mark Letestu', 'Jack Roslovic', 'Mathieu Perreault',
#        'Kyle Connor', 'Rhett Gardner', 'Jonathan Marchessault',
#        'Cody Glass', 'Paul Stastny', 'Tomas Nosek', 'William Karlsson',
#        'Brad Marchand', 'Reilly Smith', 'David Pastrnak', 'Danton Heinen',
#        'Brayden Point', 'Derek Grant', 'Isac Lundestrom', 'Adam Henrique',
#        'Ryan Getzlaf', 'Devin Shore', 'Carter Rowney',
#        'Jakob Silfverberg', 'Ondrej Kase', 'Daniel Carr',
#        'Nathan MacKinnon', 'Gabriel Landeskog', 'Andre Burakovsky',
#        'Nazem Kadri', 'Colin Wilson', 'Tyson Jost',
#        'Pierre-Edouard Bellemare', 'Joonas Donskoi',
#        'Vladislav Namestnikov', 'Nico Hischier', 'Travis Zajac',
#        'Jesper Bratt', 'Brett Ritchie', 'Pavel Zacha', 'Jack Hughes',
#        'Kevin Rooney', 'Blake Coleman', 'Andreas Athanasiou',
#        'Joel Eriksson Ek', 'Ryan Hartman', 'Luke Kunin', 'Mikko Koivu',
#        'Eric Staal', 'Jason Zucker', 'Victor Rask', 'Mats Zuccarello',
#        'Marcus Foligno', 'Blake Wheeler', 'Patrik Laine', 'Sam Steel',
#        'Nick Ritchie', 'Troy Terry', 'Karson Kuhlman', 'Mikko Rantanen',
#        'Gerald Mayhew', 'Ryan Donato', 'J.T. Compher', 'Matt Nieto',
#        'Kasperi Kapanen', 'Mika Zibanejad', 'Brett Howden', 'Ryan Strome',
#        'Brendan Lemieux', 'Chris Kreider', 'Lias Andersson',
#        'Pavel Buchnevich', 'Cody Eakin', 'Ryan Reaves', 'Max Pacioretty',
#        'Kirby Dach', 'Alex DeBrincat', 'Cam Atkinson', 'Brian Boyle',
#        'Elias Lindholm', 'Derek Ryan', 'Mark Jankowski',
#        'Mikael Backlund', 'Sean Monahan', 'Austin Czarnik',
#        'Andrew Mangiapane', 'Connor McDavid', 'Leon Draisaitl',
#        'Riley Sheahan', 'Ryan Nugent-Hopkins', 'Sam Gagner',
#        'Jujhar Khaira', 'Markus Granlund', 'Logan Couture',
#        'Barclay Goodrow', 'Dylan Gambrell', 'Joe Thornton', 'Tomas Hertl',
#        'Evander Kane', 'Patrick Marleau', 'Brandon Sutter', 'J.T. Miller',
#        'Bo Horvat', 'Jay Beagle', 'Elias Pettersson', 'Tyler Motte',
#        'Micheal Ferland', 'Josh Leivo', 'Paul Byron', 'Peter Cehlarik',
#        'Micheal Haley', 'Greg McKegg', 'Melker Karlsson', 'Timo Meier',
#        'Filip Chytil', 'Claude Giroux', 'Michael Raffl',
#        'Mikhail Vorobyev', 'Tyler Pitlick', 'Jakub Voracek',
#        'Kevin Hayes', 'Sean Couturier', 'Joel Farabee', 'Taylor Hall',
#        'Wayne Simmonds', 'John Hayden', 'Cal Clutterbuck',
#        'Cole Bardreau', 'Michael Dal Colle', 'Colby Cave', 'Gaetan Haas',
#        'J.C. Beaudin', 'Travis Konecny', 'Morgan Rielly',
#        'German Rubtsov', 'Sam Bennett', 'Alex Galchenyuk',
#        'Ryan Poehling', 'Artturi Lehkonen', 'Anze Kopitar',
#        'Adrian Kempe', 'Ilya Kovalchuk', 'Blake Lizotte',
#        'Michael Amadio', 'Jeff Carter', 'Tyler Toffoli', 'Nicolas Roy',
#        'Brandon Pirri', 'Mark Pysyk', 'James van Riemsdyk',
#        'Andy Andreoff', 'Oskar Lindblom', 'Zack Smith', 'Mark Stone',
#        'Zach Senyshyn', 'Dominik Kubalik', 'Christian Fischer',
#        'Anders Bjork', 'Joakim Nordstrom', 'Bryan Rust', 'Zach Hyman',
#        'Jesper Boqvist', 'Kyle Palmieri', 'David Gustafsson',
#        'Otto Koivula', 'William Carrier', 'Alex Tuch', 'Tim Gettinger',
#        'Barrett Hayton', 'Tyler Graovac', 'Adam Gaudette', 'Brock Boeser',
#        'Tim Schaller', 'John Carlson', 'Zach Parise', 'T.J. Tynan',
#        'Vladislav Kamenev', 'Milan Lucic', 'Jack Studnicka',
#        'Brendan Gaunce', 'Tanner Pearson', 'Alex Ovechkin', 'Boo Nieves',
#        'Jesper Fast', 'Ryan Dzingel', 'Mackenzie MacEachern',
#        'Warren Foegele', 'Morgan Frost', 'Rocco Grimaldi',
#        'Marcus Sorensen', 'Noah Gregor', 'Matt Calvert',
#        'Nikolai Prokhorkin', 'Trevor Lewis', 'Dustin Brown',
#        'Stefan Noesen', 'Aleksi Saarela', 'Nikita Kucherov',
#        'Alex Iafallo', 'Tobias Rieder', 'Corey Perry', 'Michael McLeod',
#        'Artemi Panarin', 'Joel Kellman', 'Kevin Labanc', 'James Neal',
#        'Scott Laughton', 'Clayton Keller', 'Connor Bunnaman',
#        'Jaret Anderson-Dolan', 'Mason Appleton', 'Gabriel Bourque',
#        'Drake Caggiula', 'Alex Nylander', 'Filip Chlapik', 'Max Jones',
#        'Rickard Rakell', 'Antti Suomela', 'Antoine Roussel',
#        'Kyle Clifford', 'Nathan Gerbe', 'Zack Kassian', 'Mason Marchment',
#        'Joey Anderson', 'Phil Kessel', 'Anton Blidh', 'Gabriel Vilardi',
#        'Austin Wagner', 'Kiefer Sherwood', 'Jayce Hawryluk',
#        'Lukas Vejdemo'], dtype=object)

# %%
temp_df = faceoff_data.loc[faceoff_data['player'] == player] \
    .groupby('opponent', sort=False, as_index=False) \
    .agg({ 'game_id': 'count', 'win': 'sum'}) \
    .rename(columns={'game_id': 'count'}) \
    .set_index('opponent')

temp_df['percent'] = (temp_df['win'] / temp_df['count']) * 100

#temp_df.loc[temp_df['count'] > 10].round({'percent': 2}).sort_values('count', ascending=False).head(30)

fig, ax = plt.subplots()

temp_df.loc[temp_df['count'] > 10].round({'percent': 2}).head(30).plot( \
    'count', \
    'percent', \
    kind='scatter', \
    ax=ax, \
    linewidth=0, \
    figsize=(8,6)
)

plt.title('{0} Faceoff Opponents'.format(player))

for k, v in temp_df.loc[temp_df['count'] > 10].round({'percent': 2}).head(30).iterrows():
    xy = [ v['count'], v['percent']]
    ax.annotate(k, xy, xytext=(10, -5), textcoords='offset points')

ax.axhline(y=50)
ax.axvline(x=25)
ax.text(34, 90, 'Dangerous', bbox=dict(facecolor='red', alpha=0.5))
ax.text(12, 85, 'Annoying', bbox=dict(facecolor='blue', alpha=0.5))
ax.text(12, 40, 'Ignorable', bbox=dict(facecolor='green', alpha=0.5))
# Out:
# Text(12, 40, 'Ignorable')
